# %% [markdown]
# <a href="https://colab.research.google.com/github/allnes/pcam_train/blob/master/pcam_fcn.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# %pip install keras-metrics
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive
# Collecting keras-metrics
#   Downloading https://files.pythonhosted.org/packages/32/c9/a87420da8e73de944e63a8e9cdcfb1f03ca31a7c4cdcdbd45d2cdf13275a/keras_metrics-1.1.0-py2.py3-none-any.whl
# Requirement already satisfied: Keras>=2.1.5 in /usr/local/lib/python3.6/dist-packages (from keras-metrics) (2.2.5)
# Requirement already satisfied: keras-preprocessing>=1.1.0 in /usr/local/lib/python3.6/dist-packages (from Keras>=2.1.5->keras-metrics) (1.1.0)
# Requirement already satisfied: scipy>=0.14 in /usr/local/lib/python3.6/dist-packages (from Keras>=2.1.5->keras-metrics) (1.3.2)
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.6/dist-packages (from Keras>=2.1.5->keras-metrics) (3.13)
# Requirement already satisfied: keras-applications>=1.0.8 in /usr/local/lib/python3.6/dist-packages (from Keras>=2.1.5->keras-metrics) (1.0.8)
# Requirement already satisfied: numpy>=1.9.1 in /usr/local/lib/python3.6/dist-packages (from Keras>=2.1.5->keras-metrics) (1.17.4)
# Requirement already satisfied: h5py in /usr/local/lib/python3.6/dist-packages (from Keras>=2.1.5->keras-metrics) (2.8.0)
# Requirement already satisfied: six>=1.9.0 in /usr/local/lib/python3.6/dist-packages (from Keras>=2.1.5->keras-metrics) (1.12.0)
# Installing collected packages: keras-metrics
# Successfully installed keras-metrics-1.1.0

# %%
cd  '/content/drive/My Drive/DL_PCAM'
# Out:
# /content/drive/My Drive/DL_PCAM

# %%
# %ls
# Out:
# camelyonpatch_level_2_split_test_meta.csv
# camelyonpatch_level_2_split_test_x.h5
# camelyonpatch_level_2_split_test_x.h5.gz
# camelyonpatch_level_2_split_test_y.h5
# camelyonpatch_level_2_split_test_y.h5.gz
# camelyonpatch_level_2_split_train_meta.csv
# camelyonpatch_level_2_split_train_x.h5
# camelyonpatch_level_2_split_train_x.h5.gz
# camelyonpatch_level_2_split_train_y.h5
# camelyonpatch_level_2_split_train_y.h5.gz
# camelyonpatch_level_2_split_valid_meta.csv
# camelyonpatch_level_2_split_valid_x.h5
# camelyonpatch_level_2_split_valid_x.h5.gz
# camelyonpatch_level_2_split_valid_y.h5
# camelyonpatch_level_2_split_valid_y.h5.gz
# model.png
# __pycache__/

# %%
import gzip
import shutil
def uzip_file(file_name, origin_name):
  with gzip.open(file_name, 'rb') as f_in:
      with open(origin_name, 'wb') as f_out:
          shutil.copyfileobj(f_in, f_out)

# %%
train_x_name = 'camelyonpatch_level_2_split_train_x.h5'
train_y_name = 'camelyonpatch_level_2_split_train_y.h5'

test_x_name = 'camelyonpatch_level_2_split_test_x.h5'
test_y_name = 'camelyonpatch_level_2_split_test_y.h5'

valid_x_name = 'camelyonpatch_level_2_split_valid_x.h5'
valid_y_name = 'camelyonpatch_level_2_split_valid_y.h5'

meta_train_name = 'camelyonpatch_level_2_split_train_meta.csv'
meta_valid_name = 'camelyonpatch_level_2_split_valid_meta.csv'
meta_test_name  = 'camelyonpatch_level_2_split_test_meta.csv'

# uzip_file(train_x_name + '.gz', train_x_name)
# uzip_file(train_y_name + '.gz', train_y_name)

# uzip_file(test_x_name + '.gz', test_x_name)
# uzip_file(test_y_name + '.gz', test_y_name)

# uzip_file(valid_x_name + '.gz', valid_x_name)
# uzip_file(valid_y_name + '.gz', valid_y_name)

# %%
from keras.utils import HDF5Matrix, normalize
import pandas as pd

x_train = HDF5Matrix(train_x_name, 'x')
y_train = HDF5Matrix(train_y_name, 'y')

x_valid = HDF5Matrix(valid_x_name, 'x')
y_valid = HDF5Matrix(valid_y_name, 'y')

x_test = HDF5Matrix(test_x_name, 'x')
y_test = HDF5Matrix(test_y_name, 'y')

meta_train = pd.read_csv(meta_train_name)
meta_valid = pd.read_csv(meta_valid_name)
meta_test  = pd.read_csv(meta_test_name)
# Out:
# Using TensorFlow backend.
# <p style="color: red;">
# The default version of TensorFlow in Colab will soon switch to TensorFlow 2.x.<br>
# We recommend you <a href="https://www.tensorflow.org/guide/migrate" target="_blank">upgrade</a> now
# or ensure your notebook will continue to use TensorFlow 1.x via the <code>%tensorflow_version 1.x</code> magic:
# <a href="https://colab.research.google.com/notebooks/tensorflow_version.ipynb" target="_blank">more info</a>.</p>

# %%
print(len(x_train))
print(type(x_train))
print(type(x_train[0]))
print(x_train[0].shape)
from matplotlib import pyplot
for i in range(0, 9):
	pyplot.subplot(330 + 1 + i)
	pyplot.imshow(x_train[i], cmap=pyplot.get_cmap('gray'))
pyplot.show()
# Out:
# 262144
# <class 'keras.utils.io_utils.HDF5Matrix'>
# <class 'numpy.ndarray'>
# (96, 96, 3)

# %%
current_core = 32
full_size = current_core * current_core * 3
original_shape = (96, 96, 3)
new_shape = (current_core, current_core, 3)
new_size = (current_core, current_core)

# %%
import cv2 as cv
import numpy as np
def resize_for_train(x_array, x_shape):
  return np.array([cv.resize(elem, dsize=x_shape) for elem in x_array])
x_train = resize_for_train(x_train, new_size)
x_valid = resize_for_train(x_valid, new_size)
x_test  = resize_for_train(x_test,  new_size)

# %%
from keras.models import Sequential
from keras.layers import Dense, Activation, Reshape, Lambda, Input, Dropout
from keras.regularizers import l2
from keras.preprocessing.image import ImageDataGenerator
import keras_metrics as ksm
import tensorflow as tf
import matplotlib.pyplot as plt

def plot_metrics(code_metrics, name_metrics):
    plt.plot(history.history[code_metrics])
    plt.plot(history.history['val_' + code_metrics])
    plt.title('Model ' + name_metrics)
    plt.ylabel(name_metrics)
    plt.xlabel('Epoch')
    plt.legend(['Train', 'Test'], loc='upper left')
    plt.show()

def show_metrics(list_metrics, name_stage, name_model):
    name_metrics = ['accuracy', 'precision', 'recall', 'f1-score']
    for i in range(4):
        print(name_model + ' ' + name_stage + ' ' + 
              name_metrics[i] + ' : ' + str(list_metrics[i + 1] * 100))

# %%
name_model = 'FCN with the same layers'
model = Sequential([
    # ---------------------------------------------------------#
    Reshape((1, 1, full_size,), input_shape=new_shape),
    # ---------------------------------------------------------#
    Dense(int(full_size), 
          kernel_initializer='random_uniform', 
          bias_initializer='random_uniform'), 
    Activation('relu'),
    # ---------------------------------------------------------#
    Dense(int(full_size), 
          kernel_initializer='random_uniform', 
          bias_initializer='random_uniform'), 
    Activation('relu'),
    # ---------------------------------------------------------#
    Dense(int(full_size), 
          kernel_initializer='random_uniform', 
          bias_initializer='random_uniform'), 
    Activation('relu'),
    # ---------------------------------------------------------#
    Dense(int(full_size / 2), 
          kernel_initializer='random_uniform', 
          bias_initializer='random_uniform'), 
    Activation('relu'),
    # ---------------------------------------------------------#
    Dense(int(full_size / 4), 
          kernel_initializer='random_uniform', 
          bias_initializer='random_uniform'), 
    Activation('relu'),
    # ---------------------------------------------------------#
    Dense(int(full_size / 8), 
          kernel_initializer='random_uniform', 
          bias_initializer='random_uniform'), 
    Activation('relu'),
    # ---------------------------------------------------------#
    Dense(1),                    
    Activation('sigmoid'),
    # ---------------------------------------------------------#
])

model.summary()
model.compile(loss='binary_crossentropy', optimizer='sgd', 
              metrics = ['binary_accuracy', 
                         ksm.binary_precision(), 
                         ksm.binary_recall(),
                         ksm.binary_f1_score()])

batch_size = 2048

datagen = ImageDataGenerator(
              preprocessing_function=lambda x: x/255.,
              width_shift_range=2,   # randomly shift images horizontally
              height_shift_range=2,  # randomly shift images vertically 
              horizontal_flip=True,  # randomly flip images
              vertical_flip=True)    # randomly flip images

history = model.fit_generator(
    datagen.flow(x_train, y_train, batch_size=batch_size),
    steps_per_epoch=len(x_train) // batch_size,
    epochs=16, 
    shuffle='batch', 
    use_multiprocessing=True,
    validation_data=datagen.flow(x_valid, y_valid, batch_size=batch_size))

plot_metrics('loss', 'Loss')
plot_metrics('binary_accuracy',  'Accuracy')

show_metrics(model.evaluate(x_train, y_train), 'train', name_model)
show_metrics(model.evaluate(x_valid, y_valid), 'valid', name_model)
show_metrics(model.evaluate(x_test,  y_test),  'test',  name_model)
# Out:
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:66: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:541: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:4432: The name tf.random_uniform is deprecated. Please use tf.random.uniform instead.
#
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# reshape_1 (Reshape)          (None, 1, 1, 3072)        0
# _________________________________________________________________
# dense_1 (Dense)              (None, 1, 1, 3072)        9440256
# _________________________________________________________________
# activation_1 (Activation)    (None, 1, 1, 3072)        0
# _________________________________________________________________
# dense_2 (Dense)              (None, 1, 1, 3072)        9440256
# _________________________________________________________________
# activation_2 (Activation)    (None, 1, 1, 3072)        0
# _________________________________________________________________
# dense_3 (Dense)              (None, 1, 1, 3072)        9440256
# _________________________________________________________________
# activation_3 (Activation)    (None, 1, 1, 3072)        0
# _________________________________________________________________
# dense_4 (Dense)              (None, 1, 1, 1536)        4720128
# _________________________________________________________________
# activation_4 (Activation)    (None, 1, 1, 1536)        0
# _________________________________________________________________
# dense_5 (Dense)              (None, 1, 1, 768)         1180416
# _________________________________________________________________
# activation_5 (Activation)    (None, 1, 1, 768)         0
# _________________________________________________________________
# dense_6 (Dense)              (None, 1, 1, 384)         295296
# _________________________________________________________________
# activation_6 (Activation)    (None, 1, 1, 384)         0
# _________________________________________________________________
# dense_7 (Dense)              (None, 1, 1, 1)           385
# _________________________________________________________________
# activation_7 (Activation)    (None, 1, 1, 1)           0
# =================================================================
# Total params: 34,516,993
# Trainable params: 34,516,993
# Non-trainable params: 0
# _________________________________________________________________
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/optimizers.py:793: The name tf.train.Optimizer is deprecated. Please use tf.compat.v1.train.Optimizer instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:3657: The name tf.log is deprecated. Please use tf.math.log instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow_core/python/ops/nn_impl.py:183: where (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:1033: The name tf.assign_add is deprecated. Please use tf.compat.v1.assign_add instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:1020: The name tf.assign is deprecated. Please use tf.compat.v1.assign instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:3005: The name tf.Session is deprecated. Please use tf.compat.v1.Session instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:190: The name tf.get_default_session is deprecated. Please use tf.compat.v1.get_default_session instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:197: The name tf.ConfigProto is deprecated. Please use tf.compat.v1.ConfigProto instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:207: The name tf.global_variables is deprecated. Please use tf.compat.v1.global_variables instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:216: The name tf.is_variable_initialized is deprecated. Please use tf.compat.v1.is_variable_initialized instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:223: The name tf.variables_initializer is deprecated. Please use tf.compat.v1.variables_initializer instead.
#
# Epoch 1/16
# 128/128 [==============================] - 81s 631ms/step - loss: 0.6537 - binary_accuracy: 0.6159 - precision: 0.6100 - recall: 0.6430 - f1_score: 0.6260 - val_loss: 0.5936 - val_binary_accuracy: 0.6726 - val_precision: 0.8315 - val_recall: 0.4322 - val_f1_score: 0.5688
# Epoch 2/16
# 128/128 [==============================] - 82s 640ms/step - loss: 0.5937 - binary_accuracy: 0.6830 - precision: 0.6787 - recall: 0.6949 - f1_score: 0.6867 - val_loss: 0.5504 - val_binary_accuracy: 0.7191 - val_precision: 0.8178 - val_recall: 0.5630 - val_f1_score: 0.6669
# Epoch 3/16
# 128/128 [==============================] - 83s 645ms/step - loss: 0.5587 - binary_accuracy: 0.7205 - precision: 0.7210 - recall: 0.7193 - f1_score: 0.7201 - val_loss: 0.5395 - val_binary_accuracy: 0.7218 - val_precision: 0.8108 - val_recall: 0.5779 - val_f1_score: 0.6748
# Epoch 4/16
# 128/128 [==============================] - 82s 641ms/step - loss: 0.5344 - binary_accuracy: 0.7386 - precision: 0.7374 - recall: 0.7410 - f1_score: 0.7392 - val_loss: 0.5207 - val_binary_accuracy: 0.7360 - val_precision: 0.7872 - val_recall: 0.6463 - val_f1_score: 0.7098
# Epoch 5/16
# 128/128 [==============================] - 82s 637ms/step - loss: 0.5245 - binary_accuracy: 0.7452 - precision: 0.7428 - recall: 0.7503 - f1_score: 0.7465 - val_loss: 0.5557 - val_binary_accuracy: 0.7096 - val_precision: 0.8518 - val_recall: 0.5068 - val_f1_score: 0.6355
# Epoch 6/16
# 128/128 [==============================] - 82s 640ms/step - loss: 0.5159 - binary_accuracy: 0.7515 - precision: 0.7478 - recall: 0.7590 - f1_score: 0.7534 - val_loss: 0.5116 - val_binary_accuracy: 0.7396 - val_precision: 0.7647 - val_recall: 0.6916 - val_f1_score: 0.7263
# Epoch 7/16
# 128/128 [==============================] - 82s 641ms/step - loss: 0.5100 - binary_accuracy: 0.7551 - precision: 0.7493 - recall: 0.7667 - f1_score: 0.7579 - val_loss: 0.5153 - val_binary_accuracy: 0.7430 - val_precision: 0.7181 - val_recall: 0.7995 - val_f1_score: 0.7566
# Epoch 8/16
# 128/128 [==============================] - 82s 639ms/step - loss: 0.5073 - binary_accuracy: 0.7559 - precision: 0.7487 - recall: 0.7704 - f1_score: 0.7594 - val_loss: 0.5084 - val_binary_accuracy: 0.7462 - val_precision: 0.7071 - val_recall: 0.8398 - val_f1_score: 0.7677
# Epoch 9/16
# 128/128 [==============================] - 82s 637ms/step - loss: 0.5049 - binary_accuracy: 0.7578 - precision: 0.7495 - recall: 0.7744 - f1_score: 0.7617 - val_loss: 0.5345 - val_binary_accuracy: 0.7316 - val_precision: 0.7819 - val_recall: 0.6418 - val_f1_score: 0.7049
# Epoch 10/16
# 128/128 [==============================] - 81s 635ms/step - loss: 0.5029 - binary_accuracy: 0.7581 - precision: 0.7500 - recall: 0.7742 - f1_score: 0.7619 - val_loss: 0.5291 - val_binary_accuracy: 0.7354 - val_precision: 0.8024 - val_recall: 0.6238 - val_f1_score: 0.7019
# Epoch 11/16
# 128/128 [==============================] - 81s 632ms/step - loss: 0.4990 - binary_accuracy: 0.7615 - precision: 0.7531 - recall: 0.7781 - f1_score: 0.7654 - val_loss: 0.4988 - val_binary_accuracy: 0.7475 - val_precision: 0.7585 - val_recall: 0.7256 - val_f1_score: 0.7417
# Epoch 12/16
# 128/128 [==============================] - 80s 627ms/step - loss: 0.4990 - binary_accuracy: 0.7609 - precision: 0.7516 - recall: 0.7794 - f1_score: 0.7653 - val_loss: 0.5302 - val_binary_accuracy: 0.7334 - val_precision: 0.7883 - val_recall: 0.6375 - val_f1_score: 0.7049
# Epoch 13/16
# 128/128 [==============================] - 81s 631ms/step - loss: 0.4976 - binary_accuracy: 0.7621 - precision: 0.7537 - recall: 0.7788 - f1_score: 0.7660 - val_loss: 0.5183 - val_binary_accuracy: 0.7393 - val_precision: 0.7779 - val_recall: 0.6692 - val_f1_score: 0.7195
# Epoch 14/16
# 128/128 [==============================] - 82s 637ms/step - loss: 0.4962 - binary_accuracy: 0.7615 - precision: 0.7527 - recall: 0.7791 - f1_score: 0.7657 - val_loss: 0.5302 - val_binary_accuracy: 0.7368 - val_precision: 0.8072 - val_recall: 0.6217 - val_f1_score: 0.7024
# Epoch 15/16
# 128/128 [==============================] - 81s 637ms/step - loss: 0.4937 - binary_accuracy: 0.7636 - precision: 0.7551 - recall: 0.7802 - f1_score: 0.7674 - val_loss: 0.5196 - val_binary_accuracy: 0.7368 - val_precision: 0.7414 - val_recall: 0.7266 - val_f1_score: 0.7339
# Epoch 16/16
# 128/128 [==============================] - 82s 638ms/step - loss: 0.4953 - binary_accuracy: 0.7629 - precision: 0.7542 - recall: 0.7799 - f1_score: 0.7669 - val_loss: 0.4871 - val_binary_accuracy: 0.7538 - val_precision: 0.7531 - val_recall: 0.7547 - val_f1_score: 0.7539
# 262144/262144 [==============================] - 25s 97us/step
# FCN with the same layers train accuracy : 76.20620727539062
# FCN with the same layers train precision : 77.6990194180394
# FCN with the same layers train recall : 73.51150512689703
# FCN with the same layers train f1-score : 75.5472742887059
# 32768/32768 [==============================] - 3s 95us/step
# FCN with the same layers valid accuracy : 75.103759765625
# FCN with the same layers valid precision : 78.7681311745584
# FCN with the same layers valid recall : 68.67249068318974
# FCN with the same layers valid f1-score : 73.37466865220668
# 32768/32768 [==============================] - 3s 95us/step
# FCN with the same layers test accuracy : 72.94921875
# FCN with the same layers test precision : 76.95730175761064
# FCN with the same layers test recall : 65.48207852436049
# FCN with the same layers test f1-score : 70.75745082507004

# %%
name_model = 'FCN with dropout'
model = Sequential([
    # ---------------------------------------------------------#
    Reshape((1, 1, full_size,), input_shape=new_shape),
    # ---------------------------------------------------------#
    Dense(int(full_size / 2), 
          kernel_initializer='random_uniform', 
          bias_initializer='random_uniform'), 
    Activation('relu'),
    Dropout(0.5),
    # ---------------------------------------------------------#
    Dense(int(full_size / 3), 
          kernel_initializer='random_uniform', 
          bias_initializer='random_uniform'), 
    Activation('relu'),
    Dropout(0.5),
    # ---------------------------------------------------------#
    Dense(int(full_size / 4), 
          kernel_initializer='random_uniform', 
          bias_initializer='random_uniform'), 
    Activation('relu'),
    Dropout(0.5),
    # ---------------------------------------------------------#
    Dense(1),                    
    Activation('sigmoid'),
    # ---------------------------------------------------------#
])

model.summary()
model.compile(loss='binary_crossentropy', optimizer='sgd', 
              metrics = ['binary_accuracy', 
                         ksm.binary_precision(), 
                         ksm.binary_recall(),
                         ksm.binary_f1_score()])

batch_size = 2048

datagen = ImageDataGenerator(
              preprocessing_function=lambda x: x/255.,
              width_shift_range=2,   # randomly shift images horizontally
              height_shift_range=2,  # randomly shift images vertically 
              horizontal_flip=True,  # randomly flip images
              vertical_flip=True)    # randomly flip images

history = model.fit_generator(
    datagen.flow(x_train, y_train, batch_size=batch_size),
    steps_per_epoch=len(x_train) // batch_size,
    epochs=16, 
    shuffle='batch', 
    use_multiprocessing=True,
    validation_data=datagen.flow(x_valid, y_valid, batch_size=batch_size))

plot_metrics('loss', 'Loss')
plot_metrics('binary_accuracy',  'Accuracy')

show_metrics(model.evaluate(x_train, y_train), 'train', name_model)
show_metrics(model.evaluate(x_valid, y_valid), 'valid', name_model)
show_metrics(model.evaluate(x_test,  y_test),  'test',  name_model)
# Out:
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:148: The name tf.placeholder_with_default is deprecated. Please use tf.compat.v1.placeholder_with_default instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:3733: calling dropout (from tensorflow.python.ops.nn_ops) with keep_prob is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `rate` instead of `keep_prob`. Rate should be set to `rate = 1 - keep_prob`.
# Model: "sequential_2"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# reshape_2 (Reshape)          (None, 1, 1, 3072)        0
# _________________________________________________________________
# dense_8 (Dense)              (None, 1, 1, 1536)        4720128
# _________________________________________________________________
# activation_8 (Activation)    (None, 1, 1, 1536)        0
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 1, 1, 1536)        0
# _________________________________________________________________
# dense_9 (Dense)              (None, 1, 1, 1024)        1573888
# _________________________________________________________________
# activation_9 (Activation)    (None, 1, 1, 1024)        0
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 1, 1, 1024)        0
# _________________________________________________________________
# dense_10 (Dense)             (None, 1, 1, 768)         787200
# _________________________________________________________________
# activation_10 (Activation)   (None, 1, 1, 768)         0
# _________________________________________________________________
# dropout_3 (Dropout)          (None, 1, 1, 768)         0
# _________________________________________________________________
# dense_11 (Dense)             (None, 1, 1, 1)           769
# _________________________________________________________________
# activation_11 (Activation)   (None, 1, 1, 1)           0
# =================================================================
# Total params: 7,081,985
# Trainable params: 7,081,985
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/16
# 128/128 [==============================] - 84s 656ms/step - loss: 0.7615 - binary_accuracy: 0.5216 - precision: 0.5223 - recall: 0.5074 - f1_score: 0.5147 - val_loss: 0.6566 - val_binary_accuracy: 0.6426 - val_precision: 0.6095 - val_recall: 0.7917 - val_f1_score: 0.6888
# Epoch 2/16
# 128/128 [==============================] - 81s 631ms/step - loss: 0.6909 - binary_accuracy: 0.5574 - precision: 0.5581 - recall: 0.5506 - f1_score: 0.5544 - val_loss: 0.6456 - val_binary_accuracy: 0.6485 - val_precision: 0.6021 - val_recall: 0.8740 - val_f1_score: 0.7130
# Epoch 3/16
# 128/128 [==============================] - 81s 635ms/step - loss: 0.6681 - binary_accuracy: 0.5894 - precision: 0.5896 - recall: 0.5885 - f1_score: 0.5891 - val_loss: 0.6322 - val_binary_accuracy: 0.6448 - val_precision: 0.5943 - val_recall: 0.9103 - val_f1_score: 0.7191
# Epoch 4/16
# 128/128 [==============================] - 80s 628ms/step - loss: 0.6500 - binary_accuracy: 0.6174 - precision: 0.6155 - recall: 0.6252 - f1_score: 0.6204 - val_loss: 0.6150 - val_binary_accuracy: 0.6480 - val_precision: 0.6002 - val_recall: 0.8851 - val_f1_score: 0.7153
# Epoch 5/16
# 128/128 [==============================] - 81s 632ms/step - loss: 0.6364 - binary_accuracy: 0.6348 - precision: 0.6322 - recall: 0.6448 - f1_score: 0.6384 - val_loss: 0.6102 - val_binary_accuracy: 0.6476 - val_precision: 0.5982 - val_recall: 0.8972 - val_f1_score: 0.7178
# Epoch 6/16
# 128/128 [==============================] - 81s 631ms/step - loss: 0.6249 - binary_accuracy: 0.6506 - precision: 0.6470 - recall: 0.6627 - f1_score: 0.6548 - val_loss: 0.6034 - val_binary_accuracy: 0.6491 - val_precision: 0.6000 - val_recall: 0.8931 - val_f1_score: 0.7177
# Epoch 7/16
# 128/128 [==============================] - 82s 639ms/step - loss: 0.6145 - binary_accuracy: 0.6617 - precision: 0.6574 - recall: 0.6753 - f1_score: 0.6663 - val_loss: 0.6039 - val_binary_accuracy: 0.6467 - val_precision: 0.5971 - val_recall: 0.8999 - val_f1_score: 0.7179
# Epoch 8/16
# 128/128 [==============================] - 81s 633ms/step - loss: 0.6067 - binary_accuracy: 0.6707 - precision: 0.6661 - recall: 0.6846 - f1_score: 0.6752 - val_loss: 0.5964 - val_binary_accuracy: 0.6517 - val_precision: 0.6027 - val_recall: 0.8879 - val_f1_score: 0.7180
# Epoch 9/16
# 128/128 [==============================] - 81s 631ms/step - loss: 0.6008 - binary_accuracy: 0.6781 - precision: 0.6733 - recall: 0.6919 - f1_score: 0.6825 - val_loss: 0.5925 - val_binary_accuracy: 0.6544 - val_precision: 0.6060 - val_recall: 0.8804 - val_f1_score: 0.7179
# Epoch 10/16
# 128/128 [==============================] - 81s 631ms/step - loss: 0.5947 - binary_accuracy: 0.6850 - precision: 0.6812 - recall: 0.6954 - f1_score: 0.6882 - val_loss: 0.5937 - val_binary_accuracy: 0.6540 - val_precision: 0.6047 - val_recall: 0.8876 - val_f1_score: 0.7193
# Epoch 11/16
# 128/128 [==============================] - 81s 631ms/step - loss: 0.5899 - binary_accuracy: 0.6900 - precision: 0.6861 - recall: 0.7005 - f1_score: 0.6932 - val_loss: 0.5936 - val_binary_accuracy: 0.6552 - val_precision: 0.6052 - val_recall: 0.8909 - val_f1_score: 0.7208
# Epoch 12/16
# 128/128 [==============================] - 81s 635ms/step - loss: 0.5855 - binary_accuracy: 0.6943 - precision: 0.6909 - recall: 0.7031 - f1_score: 0.6970 - val_loss: 0.5954 - val_binary_accuracy: 0.6576 - val_precision: 0.6066 - val_recall: 0.8954 - val_f1_score: 0.7232
# Epoch 13/16
# 128/128 [==============================] - 82s 637ms/step - loss: 0.5817 - binary_accuracy: 0.6980 - precision: 0.6951 - recall: 0.7056 - f1_score: 0.7003 - val_loss: 0.5956 - val_binary_accuracy: 0.6585 - val_precision: 0.6072 - val_recall: 0.8961 - val_f1_score: 0.7239
# Epoch 14/16
# 128/128 [==============================] - 82s 640ms/step - loss: 0.5788 - binary_accuracy: 0.7015 - precision: 0.6988 - recall: 0.7083 - f1_score: 0.7035 - val_loss: 0.6000 - val_binary_accuracy: 0.6569 - val_precision: 0.6049 - val_recall: 0.9030 - val_f1_score: 0.7245
# Epoch 15/16
# 128/128 [==============================] - 81s 633ms/step - loss: 0.5754 - binary_accuracy: 0.7046 - precision: 0.7013 - recall: 0.7127 - f1_score: 0.7070 - val_loss: 0.5961 - val_binary_accuracy: 0.6609 - val_precision: 0.6091 - val_recall: 0.8964 - val_f1_score: 0.7254
# Epoch 16/16
# 128/128 [==============================] - 82s 638ms/step - loss: 0.5725 - binary_accuracy: 0.7079 - precision: 0.7058 - recall: 0.7132 - f1_score: 0.7094 - val_loss: 0.5982 - val_binary_accuracy: 0.6632 - val_precision: 0.6105 - val_recall: 0.9004 - val_f1_score: 0.7276
# 262144/262144 [==============================] - 24s 90us/step
# FCN with dropout train accuracy : 68.51768493652344
# FCN with dropout train precision : 62.914012992991154
# FCN with dropout train recall : 90.2137756346968
# FCN with dropout train f1-score : 74.13037610797134
# 32768/32768 [==============================] - 3s 89us/step
# FCN with dropout valid accuracy : 68.2586669921875
# FCN with dropout valid precision : 63.35242527267159
# FCN with dropout valid recall : 86.51006711356614
# FCN with dropout valid f1-score : 73.1358269240132
# 32768/32768 [==============================] - 3s 89us/step
# FCN with dropout test accuracy : 67.2637939453125
# FCN with dropout test precision : 62.96228319692134
# FCN with dropout test recall : 83.7882396038115
# FCN with dropout test f1-score : 71.89750891971325

# %%
name_model = 'FCN without dropout'
model = Sequential([
    # ---------------------------------------------------------#
    Reshape((1, 1, full_size,), input_shape=new_shape),
    # ---------------------------------------------------------#
    Dense(int(full_size / 2), 
          kernel_initializer='random_uniform', 
          bias_initializer='random_uniform'), 
    Activation('relu'),
    # ---------------------------------------------------------#
    Dense(int(full_size / 3), 
          kernel_initializer='random_uniform', 
          bias_initializer='random_uniform'), 
    Activation('relu'),
    # ---------------------------------------------------------#
    Dense(int(full_size / 4), 
          kernel_initializer='random_uniform', 
          bias_initializer='random_uniform'), 
    Activation('relu'),
    # ---------------------------------------------------------#
    Dense(1),                    
    Activation('sigmoid'),
    # ---------------------------------------------------------#
])

model.summary()
model.compile(loss='binary_crossentropy', optimizer='sgd', 
              metrics = ['binary_accuracy', 
                         ksm.binary_precision(), 
                         ksm.binary_recall(),
                         ksm.binary_f1_score()])

batch_size = 2048

datagen = ImageDataGenerator(
              preprocessing_function=lambda x: x/255.,
              width_shift_range=2,   # randomly shift images horizontally
              height_shift_range=2,  # randomly shift images vertically 
              horizontal_flip=True,  # randomly flip images
              vertical_flip=True)    # randomly flip images

history = model.fit_generator(
    datagen.flow(x_train, y_train, batch_size=batch_size),
    steps_per_epoch=len(x_train) // batch_size,
    epochs=16, 
    shuffle='batch', 
    use_multiprocessing=True,
    validation_data=datagen.flow(x_valid, y_valid, batch_size=batch_size))

plot_metrics('loss', 'Loss')
plot_metrics('binary_accuracy',  'Accuracy')

show_metrics(model.evaluate(x_train, y_train), 'train', name_model)
show_metrics(model.evaluate(x_valid, y_valid), 'valid', name_model)
show_metrics(model.evaluate(x_test,  y_test),  'test',  name_model)
# Out:
# Model: "sequential_3"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# reshape_3 (Reshape)          (None, 1, 1, 3072)        0
# _________________________________________________________________
# dense_12 (Dense)             (None, 1, 1, 1536)        4720128
# _________________________________________________________________
# activation_12 (Activation)   (None, 1, 1, 1536)        0
# _________________________________________________________________
# dense_13 (Dense)             (None, 1, 1, 1024)        1573888
# _________________________________________________________________
# activation_13 (Activation)   (None, 1, 1, 1024)        0
# _________________________________________________________________
# dense_14 (Dense)             (None, 1, 1, 768)         787200
# _________________________________________________________________
# activation_14 (Activation)   (None, 1, 1, 768)         0
# _________________________________________________________________
# dense_15 (Dense)             (None, 1, 1, 1)           769
# _________________________________________________________________
# activation_15 (Activation)   (None, 1, 1, 1)           0
# =================================================================
# Total params: 7,081,985
# Trainable params: 7,081,985
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/16
# 128/128 [==============================] - 83s 651ms/step - loss: 0.6564 - binary_accuracy: 0.6058 - precision: 0.6004 - recall: 0.6327 - f1_score: 0.6161 - val_loss: 0.6160 - val_binary_accuracy: 0.6603 - val_precision: 0.6114 - val_recall: 0.8781 - val_f1_score: 0.7209
# Epoch 2/16
# 128/128 [==============================] - 80s 626ms/step - loss: 0.6152 - binary_accuracy: 0.6582 - precision: 0.6481 - recall: 0.6921 - f1_score: 0.6694 - val_loss: 0.5791 - val_binary_accuracy: 0.7018 - val_precision: 0.7177 - val_recall: 0.6645 - val_f1_score: 0.6901
# Epoch 3/16
# 128/128 [==============================] - 81s 634ms/step - loss: 0.5983 - binary_accuracy: 0.6810 - precision: 0.6725 - recall: 0.7054 - f1_score: 0.6886 - val_loss: 0.6427 - val_binary_accuracy: 0.5928 - val_precision: 0.5532 - val_recall: 0.9604 - val_f1_score: 0.7021
# Epoch 4/16
# 128/128 [==============================] - 81s 634ms/step - loss: 0.5805 - binary_accuracy: 0.7029 - precision: 0.6942 - recall: 0.7254 - f1_score: 0.7094 - val_loss: 0.5921 - val_binary_accuracy: 0.6988 - val_precision: 0.8366 - val_recall: 0.4934 - val_f1_score: 0.6207
# Epoch 5/16
# 128/128 [==============================] - 81s 635ms/step - loss: 0.5733 - binary_accuracy: 0.7117 - precision: 0.7059 - recall: 0.7257 - f1_score: 0.7157 - val_loss: 0.5526 - val_binary_accuracy: 0.7218 - val_precision: 0.7627 - val_recall: 0.6433 - val_f1_score: 0.6979
# Epoch 6/16
# 128/128 [==============================] - 81s 630ms/step - loss: 0.5621 - binary_accuracy: 0.7224 - precision: 0.7187 - recall: 0.7308 - f1_score: 0.7247 - val_loss: 0.5575 - val_binary_accuracy: 0.7171 - val_precision: 0.6919 - val_recall: 0.7817 - val_f1_score: 0.7341
# Epoch 7/16
# 128/128 [==============================] - 81s 632ms/step - loss: 0.5546 - binary_accuracy: 0.7287 - precision: 0.7260 - recall: 0.7348 - f1_score: 0.7304 - val_loss: 0.5452 - val_binary_accuracy: 0.7251 - val_precision: 0.7314 - val_recall: 0.7107 - val_f1_score: 0.7209
# Epoch 8/16
# 128/128 [==============================] - 81s 633ms/step - loss: 0.5476 - binary_accuracy: 0.7346 - precision: 0.7333 - recall: 0.7373 - f1_score: 0.7353 - val_loss: 0.5453 - val_binary_accuracy: 0.7264 - val_precision: 0.7217 - val_recall: 0.7363 - val_f1_score: 0.7289
# Epoch 9/16
# 128/128 [==============================] - 81s 631ms/step - loss: 0.5457 - binary_accuracy: 0.7349 - precision: 0.7331 - recall: 0.7387 - f1_score: 0.7359 - val_loss: 0.5413 - val_binary_accuracy: 0.7260 - val_precision: 0.7612 - val_recall: 0.6578 - val_f1_score: 0.7058
# Epoch 10/16
# 128/128 [==============================] - 81s 629ms/step - loss: 0.5371 - binary_accuracy: 0.7411 - precision: 0.7405 - recall: 0.7424 - f1_score: 0.7414 - val_loss: 0.5428 - val_binary_accuracy: 0.7257 - val_precision: 0.7792 - val_recall: 0.6291 - val_f1_score: 0.6962
# Epoch 11/16
# 128/128 [==============================] - 81s 631ms/step - loss: 0.5342 - binary_accuracy: 0.7437 - precision: 0.7435 - recall: 0.7441 - f1_score: 0.7438 - val_loss: 0.5386 - val_binary_accuracy: 0.7292 - val_precision: 0.7354 - val_recall: 0.7153 - val_f1_score: 0.7252
# Epoch 12/16
# 128/128 [==============================] - 80s 623ms/step - loss: 0.5309 - binary_accuracy: 0.7457 - precision: 0.7455 - recall: 0.7461 - f1_score: 0.7458 - val_loss: 0.5386 - val_binary_accuracy: 0.7286 - val_precision: 0.7211 - val_recall: 0.7446 - val_f1_score: 0.7327
# Epoch 13/16
# 128/128 [==============================] - 81s 635ms/step - loss: 0.5269 - binary_accuracy: 0.7488 - precision: 0.7487 - recall: 0.7490 - f1_score: 0.7488 - val_loss: 0.5336 - val_binary_accuracy: 0.7296 - val_precision: 0.7493 - val_recall: 0.6892 - val_f1_score: 0.7180
# Epoch 14/16
# 128/128 [==============================] - 81s 636ms/step - loss: 0.5262 - binary_accuracy: 0.7485 - precision: 0.7483 - recall: 0.7487 - f1_score: 0.7485 - val_loss: 0.5508 - val_binary_accuracy: 0.7206 - val_precision: 0.6867 - val_recall: 0.8104 - val_f1_score: 0.7434
# Epoch 15/16
# 128/128 [==============================] - 81s 630ms/step - loss: 0.5225 - binary_accuracy: 0.7511 - precision: 0.7502 - recall: 0.7530 - f1_score: 0.7516 - val_loss: 0.5409 - val_binary_accuracy: 0.7270 - val_precision: 0.7921 - val_recall: 0.6148 - val_f1_score: 0.6923
# Epoch 16/16
# 128/128 [==============================] - 81s 633ms/step - loss: 0.5207 - binary_accuracy: 0.7520 - precision: 0.7512 - recall: 0.7535 - f1_score: 0.7524 - val_loss: 0.5326 - val_binary_accuracy: 0.7290 - val_precision: 0.7683 - val_recall: 0.6550 - val_f1_score: 0.7071
# 262144/262144 [==============================] - 23s 89us/step
# FCN without dropout train accuracy : 75.40931701660156
# FCN without dropout train precision : 77.14413790286714
# FCN without dropout train recall : 72.2137451171324
# FCN without dropout train f1-score : 74.59755891243861
# 32768/32768 [==============================] - 3s 87us/step
# FCN without dropout valid accuracy : 73.1414794921875
# FCN without dropout valid precision : 77.50799651005009
# FCN without dropout valid recall : 65.13531675688718
# FCN without dropout valid f1-score : 70.78505727781221
# 32768/32768 [==============================] - 3s 86us/step
# FCN without dropout test accuracy : 70.6939697265625
# FCN without dropout test precision : 75.0926063114899
# FCN without dropout test recall : 61.891677352006525
# FCN without dropout test f1-score : 67.85606199158694
