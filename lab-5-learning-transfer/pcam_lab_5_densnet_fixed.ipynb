# %% [markdown]
# <a href="https://colab.research.google.com/github/Lenferd/pcam_train/blob/lab5-optimize-train-param/lab-5-learning-transfer/pcam_lab_5_densnet_fixed.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Keras imports

# %%
import os
import numpy as np
import tensorflow as tf
# %pip install keras-metrics
os.environ['TF_CPP_MIN_LOG_LEVEL'] = '2'
# Out:
# <p style="color: red;">
# The default version of TensorFlow in Colab will soon switch to TensorFlow 2.x.<br>
# We recommend you <a href="https://www.tensorflow.org/guide/migrate" target="_blank">upgrade</a> now
# or ensure your notebook will continue to use TensorFlow 1.x via the <code>%tensorflow_version 1.x</code> magic:
# <a href="https://colab.research.google.com/notebooks/tensorflow_version.ipynb" target="_blank">more info</a>.</p>
# Collecting keras-metrics
#   Downloading https://files.pythonhosted.org/packages/32/c9/a87420da8e73de944e63a8e9cdcfb1f03ca31a7c4cdcdbd45d2cdf13275a/keras_metrics-1.1.0-py2.py3-none-any.whl
# Requirement already satisfied: Keras>=2.1.5 in /usr/local/lib/python3.6/dist-packages (from keras-metrics) (2.2.5)
# Requirement already satisfied: keras-applications>=1.0.8 in /usr/local/lib/python3.6/dist-packages (from Keras>=2.1.5->keras-metrics) (1.0.8)
# Requirement already satisfied: h5py in /usr/local/lib/python3.6/dist-packages (from Keras>=2.1.5->keras-metrics) (2.8.0)
# Requirement already satisfied: keras-preprocessing>=1.1.0 in /usr/local/lib/python3.6/dist-packages (from Keras>=2.1.5->keras-metrics) (1.1.0)
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.6/dist-packages (from Keras>=2.1.5->keras-metrics) (3.13)
# Requirement already satisfied: six>=1.9.0 in /usr/local/lib/python3.6/dist-packages (from Keras>=2.1.5->keras-metrics) (1.12.0)
# Requirement already satisfied: scipy>=0.14 in /usr/local/lib/python3.6/dist-packages (from Keras>=2.1.5->keras-metrics) (1.4.1)
# Requirement already satisfied: numpy>=1.9.1 in /usr/local/lib/python3.6/dist-packages (from Keras>=2.1.5->keras-metrics) (1.17.5)
# Installing collected packages: keras-metrics
# Successfully installed keras-metrics-1.1.0

# %% [markdown]
# # Load dataset

# %%
from google.colab import drive
drive.mount('/content/drive')
os.chdir('/content/drive/My Drive/DL_PCAM')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive

# %%
train_x_name = 'camelyonpatch_level_2_split_train_x.h5'
train_y_name = 'camelyonpatch_level_2_split_train_y.h5'

test_x_name = 'camelyonpatch_level_2_split_test_x.h5'
test_y_name = 'camelyonpatch_level_2_split_test_y.h5'

valid_x_name = 'camelyonpatch_level_2_split_valid_x.h5'
valid_y_name = 'camelyonpatch_level_2_split_valid_y.h5'

meta_train_name = 'camelyonpatch_level_2_split_train_meta.csv'
meta_valid_name = 'camelyonpatch_level_2_split_valid_meta.csv'
meta_test_name  = 'camelyonpatch_level_2_split_test_meta.csv'

# %%
from keras.utils import HDF5Matrix, normalize

x_train = HDF5Matrix(train_x_name, 'x', 
                     normalizer=lambda x: np.true_divide(x, 255.))
y_train = HDF5Matrix(train_y_name, 'y')

x_valid = HDF5Matrix(valid_x_name, 'x', 
                     normalizer=lambda x: np.true_divide(x, 255.))
y_valid = HDF5Matrix(valid_y_name, 'y')

x_test  = HDF5Matrix(test_x_name, 'x', 
                     normalizer=lambda x: np.true_divide(x, 255.))
y_test  = HDF5Matrix(test_y_name, 'y')
# Out:
# Using TensorFlow backend.

# %% [markdown]
# # Reshape labels

# %%
# Input image dimensions.
input_shape = x_train.shape[1:]

y_train = np.array(y_train)
y_train = y_train.reshape((y_train.shape[0], 1))

y_valid = np.array(y_valid)
y_valid = y_valid.reshape((y_valid.shape[0], 1))

y_test = np.array(y_test)
y_test = y_test.reshape((y_test.shape[0], 1))

print('input share:', input_shape)
print('x_train shape:', x_train.shape)

print(x_train.shape[0], 'train samples')
print(x_test.shape[0], 'test samples')
print('y_train shape:', y_train.shape)
# Out:
# input share: (96, 96, 3)
# x_train shape: (262144, 96, 96, 3)
# 262144 train samples
# 32768 test samples
# y_train shape: (262144, 1)

# %%
y_train = y_train.reshape((y_train.shape[0], 1))
print("1 in train : {}".format(np.count_nonzero(y_train == 1)))
print("0 in train : {}".format(np.count_nonzero(y_train == 0)))

y_valid = y_valid.reshape((y_valid.shape[0], 1))
print("1 in valid : {}".format(np.count_nonzero(y_valid == 1)))
print("0 in valid : {}".format(np.count_nonzero(y_valid == 0)))
# Out:
# 1 in train : 131072
# 0 in train : 131072
# 1 in valid : 16369
# 0 in valid : 16399

# %% [markdown]
# # Prepare Densnet121 model

# %%
from keras.applications.densenet import DenseNet121
from keras.models import Sequential
from keras import layers

def denseNet_trained_freezed(input_shape, num_classes=1):
  densenet_model = DenseNet121(weights='imagenet', include_top=False, input_shape=input_shape)
  for layer in densenet_model.layers:
    layer.trainable = False

  model = Sequential()
  model.add(densenet_model)
  model.add(layers.GlobalAveragePooling2D())
  model.add(layers.Dense(1, activation='sigmoid', name='fc1', kernel_initializer = 'he_normal'))
  return model

# %%
model = denseNet_trained_freezed(input_shape)
# Out:
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:66: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:541: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:4432: The name tf.random_uniform is deprecated. Please use tf.random.uniform instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:190: The name tf.get_default_session is deprecated. Please use tf.compat.v1.get_default_session instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:197: The name tf.ConfigProto is deprecated. Please use tf.compat.v1.ConfigProto instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:203: The name tf.Session is deprecated. Please use tf.compat.v1.Session instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:207: The name tf.global_variables is deprecated. Please use tf.compat.v1.global_variables instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:216: The name tf.is_variable_initialized is deprecated. Please use tf.compat.v1.is_variable_initialized instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:223: The name tf.variables_initializer is deprecated. Please use tf.compat.v1.variables_initializer instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:2041: The name tf.nn.fused_batch_norm is deprecated. Please use tf.compat.v1.nn.fused_batch_norm instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:148: The name tf.placeholder_with_default is deprecated. Please use tf.compat.v1.placeholder_with_default instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:4267: The name tf.nn.max_pool is deprecated. Please use tf.nn.max_pool2d instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:4271: The name tf.nn.avg_pool is deprecated. Please use tf.nn.avg_pool2d instead.
#
# Downloading data from https://github.com/keras-team/keras-applications/releases/download/densenet/densenet121_weights_tf_dim_ordering_tf_kernels_notop.h5
# 29089792/29084464 [==============================] - 3s 0us/step
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:4479: The name tf.truncated_normal is deprecated. Please use tf.random.truncated_normal instead.

# %% [markdown]
# ## Densnet info

# %% [markdown]
# ### Summary

# %%
model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# densenet121 (Model)          (None, 3, 3, 1024)        7037504
# _________________________________________________________________
# global_average_pooling2d_1 ( (None, 1024)              0
# _________________________________________________________________
# fc1 (Dense)                  (None, 1)                 1025
# =================================================================
# Total params: 7,038,529
# Trainable params: 1,025
# Non-trainable params: 7,037,504
# _________________________________________________________________

# %% [markdown]
# ### Plot

# %%
from keras.utils.vis_utils import plot_model
plot_model(model, show_shapes=True, show_layer_names=True)

# %% [markdown]
# #Compile & run model

# %%
# PARAMS
LEARN_RATE = 1e-4   # 1e-3
BATCH_SIZE = 256
EPOCHS = 40

# %%
from keras.optimizers import Adam
import keras_metrics as k_metrics

model.compile(loss='binary_crossentropy',
              optimizer=Adam(lr=LEARN_RATE),
              metrics = ['binary_accuracy', 
                          k_metrics.binary_precision(), 
                          k_metrics.binary_recall(),
                          k_metrics.binary_f1_score()
                        ])

# %%
history = model.fit(x_train, y_train,
          batch_size=BATCH_SIZE,
          epochs=EPOCHS,
          validation_data=(x_test, y_test),
          shuffle="batch")
# Out:
# Train on 262144 samples, validate on 32768 samples
# Epoch 1/40
# 262144/262144 [==============================] - 143s 546us/step - loss: 0.5590 - binary_accuracy: 0.7166 - precision: 0.7226 - recall: 0.7032 - f1_score: 0.7128 - val_loss: 0.5672 - val_binary_accuracy: 0.7073 - val_precision: 0.7479 - val_recall: 0.6250 - val_f1_score: 0.6810
# Epoch 2/40
# 262144/262144 [==============================] - 140s 532us/step - loss: 0.5552 - binary_accuracy: 0.7192 - precision: 0.7253 - recall: 0.7057 - f1_score: 0.7153 - val_loss: 0.5676 - val_binary_accuracy: 0.7050 - val_precision: 0.7508 - val_recall: 0.6135 - val_f1_score: 0.6752
# Epoch 3/40
# 262144/262144 [==============================] - 139s 531us/step - loss: 0.5525 - binary_accuracy: 0.7215 - precision: 0.7272 - recall: 0.7090 - f1_score: 0.7180 - val_loss: 0.5667 - val_binary_accuracy: 0.7047 - val_precision: 0.7515 - val_recall: 0.6113 - val_f1_score: 0.6742
# Epoch 4/40
# 262144/262144 [==============================] - 139s 532us/step - loss: 0.5515 - binary_accuracy: 0.7222 - precision: 0.7272 - recall: 0.7113 - f1_score: 0.7191 - val_loss: 0.5666 - val_binary_accuracy: 0.7029 - val_precision: 0.7640 - val_recall: 0.5867 - val_f1_score: 0.6637
# Epoch 5/40
# 262144/262144 [==============================] - 139s 530us/step - loss: 0.5490 - binary_accuracy: 0.7237 - precision: 0.7299 - recall: 0.7102 - f1_score: 0.7199 - val_loss: 0.5681 - val_binary_accuracy: 0.6996 - val_precision: 0.7686 - val_recall: 0.5709 - val_f1_score: 0.6551
# Epoch 6/40
# 262144/262144 [==============================] - 139s 532us/step - loss: 0.5471 - binary_accuracy: 0.7254 - precision: 0.7305 - recall: 0.7144 - f1_score: 0.7224 - val_loss: 0.5754 - val_binary_accuracy: 0.6866 - val_precision: 0.7993 - val_recall: 0.4978 - val_f1_score: 0.6135
# Epoch 7/40
# 262144/262144 [==============================] - 139s 530us/step - loss: 0.5459 - binary_accuracy: 0.7265 - precision: 0.7328 - recall: 0.7128 - f1_score: 0.7227 - val_loss: 0.5724 - val_binary_accuracy: 0.6920 - val_precision: 0.7905 - val_recall: 0.5222 - val_f1_score: 0.6289
# Epoch 8/40
# 262144/262144 [==============================] - 139s 531us/step - loss: 0.5427 - binary_accuracy: 0.7286 - precision: 0.7351 - recall: 0.7149 - f1_score: 0.7248 - val_loss: 0.5689 - val_binary_accuracy: 0.6962 - val_precision: 0.7739 - val_recall: 0.5539 - val_f1_score: 0.6457
# Epoch 9/40
# 262144/262144 [==============================] - 140s 532us/step - loss: 0.5432 - binary_accuracy: 0.7284 - precision: 0.7341 - recall: 0.7162 - f1_score: 0.7250 - val_loss: 0.5735 - val_binary_accuracy: 0.6908 - val_precision: 0.7919 - val_recall: 0.5174 - val_f1_score: 0.6258
# Epoch 10/40
# 262144/262144 [==============================] - 139s 531us/step - loss: 0.5408 - binary_accuracy: 0.7296 - precision: 0.7345 - recall: 0.7192 - f1_score: 0.7268 - val_loss: 0.5739 - val_binary_accuracy: 0.6901 - val_precision: 0.7948 - val_recall: 0.5121 - val_f1_score: 0.6229
# Epoch 11/40
# 262144/262144 [==============================] - 139s 530us/step - loss: 0.5411 - binary_accuracy: 0.7292 - precision: 0.7358 - recall: 0.7153 - f1_score: 0.7254 - val_loss: 0.5752 - val_binary_accuracy: 0.6877 - val_precision: 0.7971 - val_recall: 0.5031 - val_f1_score: 0.6169
# Epoch 12/40
# 262144/262144 [==============================] - 139s 531us/step - loss: 0.5398 - binary_accuracy: 0.7308 - precision: 0.7370 - recall: 0.7179 - f1_score: 0.7273 - val_loss: 0.5751 - val_binary_accuracy: 0.6888 - val_precision: 0.7954 - val_recall: 0.5081 - val_f1_score: 0.6201
# Epoch 13/40
# 262144/262144 [==============================] - 139s 530us/step - loss: 0.5396 - binary_accuracy: 0.7305 - precision: 0.7366 - recall: 0.7175 - f1_score: 0.7269 - val_loss: 0.5727 - val_binary_accuracy: 0.6917 - val_precision: 0.7868 - val_recall: 0.5256 - val_f1_score: 0.6302
# Epoch 14/40
# 262144/262144 [==============================] - 139s 531us/step - loss: 0.5382 - binary_accuracy: 0.7321 - precision: 0.7382 - recall: 0.7193 - f1_score: 0.7286 - val_loss: 0.5722 - val_binary_accuracy: 0.6934 - val_precision: 0.7797 - val_recall: 0.5388 - val_f1_score: 0.6372
# Epoch 15/40
# 262144/262144 [==============================] - 139s 530us/step - loss: 0.5384 - binary_accuracy: 0.7318 - precision: 0.7375 - recall: 0.7200 - f1_score: 0.7286 - val_loss: 0.5725 - val_binary_accuracy: 0.6927 - val_precision: 0.7803 - val_recall: 0.5362 - val_f1_score: 0.6356
# Epoch 16/40
# 262144/262144 [==============================] - 139s 532us/step - loss: 0.5376 - binary_accuracy: 0.7326 - precision: 0.7387 - recall: 0.7199 - f1_score: 0.7292 - val_loss: 0.5759 - val_binary_accuracy: 0.6876 - val_precision: 0.7911 - val_recall: 0.5095 - val_f1_score: 0.6198
# Epoch 17/40
# 262144/262144 [==============================] - 139s 530us/step - loss: 0.5360 - binary_accuracy: 0.7339 - precision: 0.7392 - recall: 0.7229 - f1_score: 0.7310 - val_loss: 0.5800 - val_binary_accuracy: 0.6811 - val_precision: 0.8021 - val_recall: 0.4804 - val_f1_score: 0.6009
# Epoch 18/40
# 262144/262144 [==============================] - 139s 532us/step - loss: 0.5363 - binary_accuracy: 0.7335 - precision: 0.7397 - recall: 0.7207 - f1_score: 0.7301 - val_loss: 0.5725 - val_binary_accuracy: 0.6929 - val_precision: 0.7710 - val_recall: 0.5486 - val_f1_score: 0.6410
# Epoch 19/40
# 262144/262144 [==============================] - 139s 530us/step - loss: 0.5350 - binary_accuracy: 0.7347 - precision: 0.7408 - recall: 0.7219 - f1_score: 0.7312 - val_loss: 0.5760 - val_binary_accuracy: 0.6882 - val_precision: 0.7872 - val_recall: 0.5155 - val_f1_score: 0.6230
# Epoch 20/40
# 262144/262144 [==============================] - 139s 531us/step - loss: 0.5347 - binary_accuracy: 0.7347 - precision: 0.7376 - recall: 0.7284 - f1_score: 0.7330 - val_loss: 0.5902 - val_binary_accuracy: 0.6707 - val_precision: 0.8191 - val_recall: 0.4379 - val_f1_score: 0.5707
# Epoch 21/40
# 262144/262144 [==============================] - 139s 529us/step - loss: 0.5351 - binary_accuracy: 0.7344 - precision: 0.7408 - recall: 0.7212 - f1_score: 0.7309 - val_loss: 0.5841 - val_binary_accuracy: 0.6769 - val_precision: 0.8082 - val_recall: 0.4635 - val_f1_score: 0.5891
# Epoch 22/40
# 262144/262144 [==============================] - 139s 531us/step - loss: 0.5352 - binary_accuracy: 0.7350 - precision: 0.7419 - recall: 0.7208 - f1_score: 0.7312 - val_loss: 0.5726 - val_binary_accuracy: 0.6930 - val_precision: 0.7717 - val_recall: 0.5478 - val_f1_score: 0.6408
# Epoch 23/40
# 262144/262144 [==============================] - 139s 529us/step - loss: 0.5339 - binary_accuracy: 0.7355 - precision: 0.7398 - recall: 0.7266 - f1_score: 0.7331 - val_loss: 0.5829 - val_binary_accuracy: 0.6797 - val_precision: 0.8054 - val_recall: 0.4734 - val_f1_score: 0.5963
# Epoch 24/40
# 262144/262144 [==============================] - 139s 532us/step - loss: 0.5327 - binary_accuracy: 0.7360 - precision: 0.7417 - recall: 0.7241 - f1_score: 0.7328 - val_loss: 0.5794 - val_binary_accuracy: 0.6836 - val_precision: 0.7917 - val_recall: 0.4980 - val_f1_score: 0.6114
# Epoch 25/40
# 262144/262144 [==============================] - 139s 530us/step - loss: 0.5317 - binary_accuracy: 0.7368 - precision: 0.7410 - recall: 0.7282 - f1_score: 0.7345 - val_loss: 0.5973 - val_binary_accuracy: 0.6647 - val_precision: 0.8322 - val_recall: 0.4122 - val_f1_score: 0.5513
# Epoch 26/40
# 262144/262144 [==============================] - 139s 531us/step - loss: 0.5323 - binary_accuracy: 0.7362 - precision: 0.7435 - recall: 0.7211 - f1_score: 0.7321 - val_loss: 0.5757 - val_binary_accuracy: 0.6903 - val_precision: 0.7734 - val_recall: 0.5380 - val_f1_score: 0.6346
# Epoch 27/40
# 262144/262144 [==============================] - 139s 530us/step - loss: 0.5325 - binary_accuracy: 0.7368 - precision: 0.7414 - recall: 0.7271 - f1_score: 0.7342 - val_loss: 0.5791 - val_binary_accuracy: 0.6851 - val_precision: 0.7899 - val_recall: 0.5040 - val_f1_score: 0.6154
# Epoch 28/40
# 262144/262144 [==============================] - 139s 530us/step - loss: 0.5308 - binary_accuracy: 0.7381 - precision: 0.7446 - recall: 0.7246 - f1_score: 0.7345 - val_loss: 0.5736 - val_binary_accuracy: 0.6929 - val_precision: 0.7639 - val_recall: 0.5582 - val_f1_score: 0.6450
# Epoch 29/40
# 262144/262144 [==============================] - 139s 529us/step - loss: 0.5308 - binary_accuracy: 0.7379 - precision: 0.7409 - recall: 0.7318 - f1_score: 0.7363 - val_loss: 0.5854 - val_binary_accuracy: 0.6780 - val_precision: 0.8030 - val_recall: 0.4715 - val_f1_score: 0.5941
# Epoch 30/40
# 262144/262144 [==============================] - 139s 529us/step - loss: 0.5311 - binary_accuracy: 0.7382 - precision: 0.7419 - recall: 0.7305 - f1_score: 0.7362 - val_loss: 0.6054 - val_binary_accuracy: 0.6576 - val_precision: 0.8395 - val_recall: 0.3893 - val_f1_score: 0.5320
# Epoch 31/40
# 262144/262144 [==============================] - 139s 530us/step - loss: 0.5313 - binary_accuracy: 0.7370 - precision: 0.7429 - recall: 0.7246 - f1_score: 0.7337 - val_loss: 0.5987 - val_binary_accuracy: 0.6655 - val_precision: 0.8270 - val_recall: 0.4181 - val_f1_score: 0.5554
# Epoch 32/40
# 262144/262144 [==============================] - 139s 530us/step - loss: 0.5321 - binary_accuracy: 0.7373 - precision: 0.7429 - recall: 0.7257 - f1_score: 0.7342 - val_loss: 0.5927 - val_binary_accuracy: 0.6709 - val_precision: 0.8145 - val_recall: 0.4423 - val_f1_score: 0.5732
# Epoch 33/40
# 262144/262144 [==============================] - 139s 529us/step - loss: 0.5305 - binary_accuracy: 0.7384 - precision: 0.7446 - recall: 0.7258 - f1_score: 0.7351 - val_loss: 0.5815 - val_binary_accuracy: 0.6826 - val_precision: 0.7928 - val_recall: 0.4940 - val_f1_score: 0.6087
# Epoch 34/40
# 262144/262144 [==============================] - 139s 529us/step - loss: 0.5305 - binary_accuracy: 0.7378 - precision: 0.7422 - recall: 0.7288 - f1_score: 0.7354 - val_loss: 0.5884 - val_binary_accuracy: 0.6751 - val_precision: 0.8063 - val_recall: 0.4605 - val_f1_score: 0.5862
# Epoch 35/40
# 262144/262144 [==============================] - 139s 529us/step - loss: 0.5303 - binary_accuracy: 0.7386 - precision: 0.7436 - recall: 0.7282 - f1_score: 0.7358 - val_loss: 0.5977 - val_binary_accuracy: 0.6671 - val_precision: 0.8236 - val_recall: 0.4250 - val_f1_score: 0.5607
# Epoch 36/40
# 262144/262144 [==============================] - 139s 530us/step - loss: 0.5293 - binary_accuracy: 0.7396 - precision: 0.7444 - recall: 0.7296 - f1_score: 0.7369 - val_loss: 0.6049 - val_binary_accuracy: 0.6601 - val_precision: 0.8368 - val_recall: 0.3974 - val_f1_score: 0.5389
# Epoch 37/40
# 262144/262144 [==============================] - 139s 529us/step - loss: 0.5296 - binary_accuracy: 0.7390 - precision: 0.7460 - recall: 0.7246 - f1_score: 0.7352 - val_loss: 0.5778 - val_binary_accuracy: 0.6878 - val_precision: 0.7705 - val_recall: 0.5347 - val_f1_score: 0.6313
# Epoch 38/40
# 262144/262144 [==============================] - 139s 531us/step - loss: 0.5284 - binary_accuracy: 0.7394 - precision: 0.7427 - recall: 0.7326 - f1_score: 0.7376 - val_loss: 0.6026 - val_binary_accuracy: 0.6625 - val_precision: 0.8337 - val_recall: 0.4057 - val_f1_score: 0.5458
# Epoch 39/40
# 262144/262144 [==============================] - 139s 529us/step - loss: 0.5282 - binary_accuracy: 0.7399 - precision: 0.7440 - recall: 0.7315 - f1_score: 0.7377 - val_loss: 0.6104 - val_binary_accuracy: 0.6547 - val_precision: 0.8426 - val_recall: 0.3800 - val_f1_score: 0.5238
# Epoch 40/40
# 262144/262144 [==============================] - 139s 532us/step - loss: 0.5266 - binary_accuracy: 0.7412 - precision: 0.7488 - recall: 0.7259 - f1_score: 0.7372 - val_loss: 0.5768 - val_binary_accuracy: 0.6888 - val_precision: 0.7727 - val_recall: 0.5344 - val_f1_score: 0.6318

# %% [markdown]
# # Metrics

# %%
from matplotlib import pyplot

# Prepare metrics functions
def plot_metrics(code_metrics, name_metrics):
    pyplot.plot(history.history[code_metrics])
    pyplot.plot(history.history['val_' + code_metrics])
    pyplot.title('Model ' + name_metrics)
    pyplot.ylabel(name_metrics)
    pyplot.xlabel('Epoch')
    pyplot.legend(['Train', 'Test'], loc='upper left')
    pyplot.show()

def show_metrics(list_metrics, name_stage, name_model):
    name_metrics = ['accuracy', 'precision', 'recall', 'f1-score']
    for i in range(4):
        print(name_model + ' ' + name_stage + ' ' + 
              name_metrics[i] + ' : ' + str(list_metrics[i + 1] * 100))

# %%
prediction = model.predict(x_train)
print(">=0.5 (1): {}".format(np.count_nonzero(prediction >= 0.5)))
print("<0.5 (0): {}".format(np.count_nonzero(prediction < 0.5)))

print("1 in train : {}".format(np.count_nonzero(y_train == 1)))
print("0 in train : {}".format(np.count_nonzero(y_train == 0)))

print(prediction)
# Out:
# >=0.5 (1): 91176
# <0.5 (0): 170968
# 1 in train : 131072
# 0 in train : 131072
# [[0.41500294]
#  [0.6191252 ]
#  [0.64493823]
#  ...
#  [0.6187241 ]
#  [0.7045405 ]
#  [0.23844522]]

# %%
prediction = model.predict(x_test)
print(">=0.5 (1): {}".format(np.count_nonzero(prediction >= 0.5)))
print("<0.5 (0): {}".format(np.count_nonzero(prediction < 0.5)))

print("1 in test : {}".format(np.count_nonzero(y_test == 1)))
print("0 in test : {}".format(np.count_nonzero(y_test == 0)))

print(prediction)
# Out:
# >=0.5 (1): 11326
# <0.5 (0): 21442
# 1 in test : 16377
# 0 in test : 16391
# [[0.24781004]
#  [0.55578667]
#  [0.34003735]
#  ...
#  [0.70707715]
#  [0.45150754]
#  [0.28179884]]

# %%
plot_metrics('loss', 'Loss')
plot_metrics('binary_accuracy',  'Binary accuracy')
plot_metrics('precision', 'precision')
plot_metrics('recall', 'recall')
plot_metrics('f1_score',  'f1_score')

# %%
name_model = "densnet121-freezed-weights"
show_metrics(model.evaluate(x_train, y_train), 'train', name_model)
show_metrics(model.evaluate(x_valid, y_valid), 'valid', name_model)
show_metrics(model.evaluate(x_test,  y_test),  'test',  name_model)
# Out:
# 262144/262144 [==============================] - 241s 919us/step
# densnet121-freezed-weights train accuracy : 70.00656127929688
# densnet121-freezed-weights train precision : 78.76085812047165
# densnet121-freezed-weights train recall : 54.787445068317574
# densnet121-freezed-weights train f1-score : 64.62239896222259
# 32768/32768 [==============================] - 31s 959us/step
# densnet121-freezed-weights valid accuracy : 63.6444091796875
# densnet121-freezed-weights valid precision : 75.30093118242901
# densnet121-freezed-weights valid recall : 40.50949966375154
# densnet121-freezed-weights valid f1-score : 52.679240733852865
# 32768/32768 [==============================] - 30s 918us/step
# densnet121-freezed-weights test accuracy : 68.8751220703125
# densnet121-freezed-weights test precision : 77.27352993044964
# densnet121-freezed-weights test recall : 53.44080112320058
# densnet121-freezed-weights test f1-score : 63.18448781998474
